# %% [markdown]
# # Beer Consumption 예측 using RNN

# %% [markdown]
# ## 1. 데이터 로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Consumo_cerveja.csv')
df.head(2)
# Out:
#          Data Temperatura Media (C) Temperatura Minima (C)  \
# 0  2015-01-01                  27,3                   23,9
# 1  2015-01-02                 27,02                   24,5
#
#   Temperatura Maxima (C) Precipitacao (mm)  Final de Semana  \
# 0                   32,5                 0              0.0
# 1                   33,5                 0              0.0
#
#    Consumo de cerveja (litros)
# 0                       25.461
# 1                       28.972

# %%
df.tail(2)
# Out:
#     Data Temperatura Media (C) Temperatura Minima (C) Temperatura Maxima (C)  \
# 939  NaN                   NaN                    NaN                    NaN
# 940  NaN                   NaN                    NaN                    NaN
#
#     Precipitacao (mm)  Final de Semana  Consumo de cerveja (litros)
# 939               NaN              NaN                          NaN
# 940               NaN              NaN                          NaN

# %% [markdown]
# ## 2. 전처리

# %%
df.info()
#Index : 941인데, non-null 갯수를 보면 분명 null값이 있다는 소리다.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 941 entries, 0 to 940
# Data columns (total 7 columns):
# Data                           365 non-null object
# Temperatura Media (C)          365 non-null object
# Temperatura Minima (C)         365 non-null object
# Temperatura Maxima (C)         365 non-null object
# Precipitacao (mm)              365 non-null object
# Final de Semana                365 non-null float64
# Consumo de cerveja (litros)    365 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 51.5+ KB

# %%
df.isnull().sum()
# Out:
# Data                           576
# Temperatura Media (C)          576
# Temperatura Minima (C)         576
# Temperatura Maxima (C)         576
# Precipitacao (mm)              576
# Final de Semana                576
# Consumo de cerveja (litros)    576
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Data                           0
# Temperatura Media (C)          0
# Temperatura Minima (C)         0
# Temperatura Maxima (C)         0
# Precipitacao (mm)              0
# Final de Semana                0
# Consumo de cerveja (litros)    0
# dtype: int64

# %%
#날짜 컬럼 datetime 변환
df['Data'] = pd.to_datetime(df['Data'], format='%Y-%m-%d')
#format YYMMDD 변환 가능

print(df.dtypes)
df.head()
# Out:
# Data                           datetime64[ns]
# Temperatura Media (C)                  object
# Temperatura Minima (C)                 object
# Temperatura Maxima (C)                 object
# Precipitacao (mm)                      object
# Final de Semana                       float64
# Consumo de cerveja (litros)           float64
# dtype: object
#         Data Temperatura Media (C) Temperatura Minima (C)  \
# 0 2015-01-01                  27,3                   23,9
# 1 2015-01-02                 27,02                   24,5
# 2 2015-01-03                 24,82                   22,4
# 3 2015-01-04                 23,98                   21,5
# 4 2015-01-05                 23,82                     21
#
#   Temperatura Maxima (C) Precipitacao (mm)  Final de Semana  \
# 0                   32,5                 0              0.0
# 1                   33,5                 0              0.0
# 2                   29,9                 0              1.0
# 3                   28,6               1,2              1.0
# 4                   28,3                 0              0.0
#
#    Consumo de cerveja (litros)
# 0                       25.461
# 1                       28.972
# 2                       30.814
# 3                       29.799
# 4                       28.900

# %%
# ,를 .으로
df.replace(regex=True, to_replace=',',value='.', inplace=True)

# %%
# object -> numeric
df['Temperatura Media (C)']=pd.to_numeric(df['Temperatura Media (C)'])
df['Temperatura Maxima (C)']=pd.to_numeric(df['Temperatura Maxima (C)'])
df['Temperatura Minima (C)']=pd.to_numeric(df['Temperatura Minima (C)'])
df['Precipitacao (mm)'] = pd.to_numeric(df['Precipitacao (mm)'])

# %%
print(df.dtypes)
df.head(2)
# Out:
# Data                           datetime64[ns]
# Temperatura Media (C)                 float64
# Temperatura Minima (C)                float64
# Temperatura Maxima (C)                float64
# Precipitacao (mm)                     float64
# Final de Semana                       float64
# Consumo de cerveja (litros)           float64
# dtype: object
#         Data  Temperatura Media (C)  Temperatura Minima (C)  \
# 0 2015-01-01                  27.30                    23.9
# 1 2015-01-02                  27.02                    24.5
#
#    Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# 0                    32.5                0.0              0.0
# 1                    33.5                0.0              0.0
#
#    Consumo de cerveja (litros)
# 0                       25.461
# 1                       28.972

# %%
# df.set_index(df['Data'], inplace=True) 이렇게하면 컬럼은 그대로 있음
# 아래 형태로. 컬럼 명만 지정해주면 됨
df.set_index('Data', inplace=True) 
df.head()
# Out:
#             Temperatura Media (C)  Temperatura Minima (C)  \
# Data
# 2015-01-01                  27.30                    23.9
# 2015-01-02                  27.02                    24.5
# 2015-01-03                  24.82                    22.4
# 2015-01-04                  23.98                    21.5
# 2015-01-05                  23.82                    21.0
#
#             Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana  \
# Data
# 2015-01-01                    32.5                0.0              0.0
# 2015-01-02                    33.5                0.0              0.0
# 2015-01-03                    29.9                0.0              1.0
# 2015-01-04                    28.6                1.2              1.0
# 2015-01-05                    28.3                0.0              0.0
#
#             Consumo de cerveja (litros)
# Data
# 2015-01-01                       25.461
# 2015-01-02                       28.972
# 2015-01-03                       30.814
# 2015-01-04                       29.799
# 2015-01-05                       28.900

# %%
df['Consumo de cerveja (litros)'].plot()

# %%
plt.plot(df['Consumo de cerveja (litros)'])
plt.grid()
plt.show()
plt.close()

# %% [markdown]
# ## 3. Train, Test set 분리

# %% [markdown]
# train, test 분리 - scale - RNN

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import keras
from keras.layers import RNN
from keras.layers import LSTM
from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.callbacks import EarlyStopping
from math import sqrt
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# callback 딥 다이브

# %%
# 손실 이력 클래스 정의
class LossHistory(keras.callbacks.Callback):
    def init(self):
        self.losses = []
        
    def on_epoch_end(self, batch, logs={}): 
        self.losses.append(logs.get('loss'))

# %%
x = df.drop(columns='Consumo de cerveja (litros)')
y = df[['Consumo de cerveja (litros)']]
x.head(2)
# Out:
#             Temperatura Media (C)  Temperatura Minima (C)  \
# Data
# 2015-01-01                  27.30                    23.9
# 2015-01-02                  27.02                    24.5
#
#             Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana
# Data
# 2015-01-01                    32.5                0.0              0.0
# 2015-01-02                    33.5                0.0              0.0

# %%
y.head(2)
# Out:
#             Consumo de cerveja (litros)
# Data
# 2015-01-01                       25.461
# 2015-01-02                       28.972

# %%
# 80%는 train데이터로, 나머지는 test 데이터로.
X_train = x[:int(len(x) * 80 / 100)]
y_train = y[:int(len(y) * 80 / 100)]
X_test = x[int(len(x) * 80 / 100) :]
y_test = y[int(len(y) * 80 / 100) :]

# %%
X_train.head(2)
# Out:
#             Temperatura Media (C)  Temperatura Minima (C)  \
# Data
# 2015-01-01                  27.30                    23.9
# 2015-01-02                  27.02                    24.5
#
#             Temperatura Maxima (C)  Precipitacao (mm)  Final de Semana
# Data
# 2015-01-01                    32.5                0.0              0.0
# 2015-01-02                    33.5                0.0              0.0

# %%
y_train.head(2)
# Out:
#             Consumo de cerveja (litros)
# Data
# 2015-01-01                       25.461
# 2015-01-02                       28.972

# %% [markdown]
# ## 4. Scale

# %%
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

# %%
X_train = scaler_X.fit_transform(X_train)
X_test = scaler_X.transform(X_test)

# %%
y_train = scaler_y.fit_transform(y_train)
y_test = scaler_y.transform(y_test)

# %% [markdown]
# ## 5. RNN

# %% [markdown]
# Window 함수를 사용하기 위해 df 형태로 변환

# %%
X_train = pd.DataFrame(X_train, columns=x.columns, index=x.index[0:292])
X_test = pd.DataFrame(X_test, columns=x.columns, index=x.index[292:])

y_train = pd.DataFrame(y_train, columns=y.columns, index=y.index[0:292])
y_test = pd.DataFrame(y_test, columns=y.columns, index=y.index[292:])

# %%
def dataset_reshape(dataset, window_size=1):
    data = []
    for i in range(len(dataset) - window_size - 1):
        change_data = dataset[i:(i+window_size)]  #한칸씩 밀려남.
        data.append(np.array(change_data))       
    return np.array(data)

# %% [markdown]
# for using RNN, df 형태를 array형태로 변환

# %% [markdown]
# * y_train = dataset_reshape(y_train['Consumo de cerveja (litros)'], 5) # (286, 5)
# * y_train = dataset_reshape(y_train, 5) # (286, 5, 1)
# * 형태비교

# %%
y_train['Consumo de cerveja (litros)'][0:5]
# Out:
# Data
# 2015-01-01    0.471221
# 2015-01-02    0.620031
# 2015-01-03    0.698101
# 2015-01-04    0.655082
# 2015-01-05    0.616979
# Name: Consumo de cerveja (litros), dtype: float64

# %%
y_train[0:5]
# Out:
#             Consumo de cerveja (litros)
# Data
# 2015-01-01                     0.471221
# 2015-01-02                     0.620031
# 2015-01-03                     0.698101
# 2015-01-04                     0.655082
# 2015-01-05                     0.616979

# %%
np.array(y_train['Consumo de cerveja (litros)'][0:5])
# Out:
# array([0.4712215 , 0.62003052, 0.69810121, 0.6550818 , 0.61697889])

# %%
np.array(y_train[0:5])
# Out:
# array([[0.4712215 ],
#        [0.62003052],
#        [0.69810121],
#        [0.6550818 ],
#        [0.61697889]])

# %%
X_train = dataset_reshape(X_train, 5)   
y_train = dataset_reshape(y_train['Consumo de cerveja (litros)'], 5) # (286, 5)
# y_train = dataset_reshape(y_train, 5) # (286, 5, 1)

X_test = dataset_reshape(X_test, 5) 
y_test = dataset_reshape(y_test['Consumo de cerveja (litros)'], 5) # (67, 5)
# y_test = dataset_reshape(y_test, 5) # (67, 5, 1)

# y_test = dataset_reshape(y_test, 5) 이렇게 안 한 이유는?
## 차원이 달라진다.

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (286, 5, 5)
# (286, 5)
# (67, 5, 5)
# (67, 5)

# %%
X_train
# Out:
# array([[[0.90225564, 0.95683453, 0.81818182, 0.        , 0.        ],
#         [0.88471178, 1.        , 0.86363636, 0.        , 0.        ],
#         [0.74686717, 0.84892086, 0.7       , 0.        , 1.        ],
#         [0.69423559, 0.78417266, 0.64090909, 0.014068  , 1.        ],
#         [0.68421053, 0.74820144, 0.62727273, 0.        , 0.        ]],
#
#        [[0.88471178, 1.        , 0.86363636, 0.        , 0.        ],
#         [0.74686717, 0.84892086, 0.7       , 0.        , 1.        ],
#         [0.69423559, 0.78417266, 0.64090909, 0.014068  , 1.        ],
#         [0.68421053, 0.74820144, 0.62727273, 0.        , 0.        ],
#         [0.68170426, 0.68345324, 0.72727273, 0.14302462, 0.        ]],
#
#        [[0.74686717, 0.84892086, 0.7       , 0.        , 1.        ],
#         [0.69423559, 0.78417266, 0.64090909, 0.014068  , 1.        ],
#         [0.68421053, 0.74820144, 0.62727273, 0.        , 0.        ],
#         [0.68170426, 0.68345324, 0.72727273, 0.14302462, 0.        ],
#         [0.69548872, 0.64028777, 0.87272727, 0.        , 0.        ]],
#
#        ...,
#
#        [[0.60025063, 0.64748201, 0.70454545, 0.        , 1.        ],
#         [0.61779449, 0.60431655, 0.68636364, 0.        , 0.        ],
#         [0.53258145, 0.53956835, 0.59545455, 0.02813599, 0.        ],
#         [0.6716792 , 0.54676259, 0.63636364, 0.        , 0.        ],
#         [0.95363409, 0.5971223 , 0.96818182, 0.        , 0.        ]],
#
#        [[0.61779449, 0.60431655, 0.68636364, 0.        , 0.        ],
#         [0.53258145, 0.53956835, 0.59545455, 0.02813599, 0.        ],
#         [0.6716792 , 0.54676259, 0.63636364, 0.        , 0.        ],
#         [0.95363409, 0.5971223 , 0.96818182, 0.        , 0.        ],
#         [0.8358396 , 0.76978417, 0.96363636, 0.        , 0.        ]],
#
#        [[0.53258145, 0.53956835, 0.59545455, 0.02813599, 0.        ],
#         [0.6716792 , 0.54676259, 0.63636364, 0.        , 0.        ],
#         [0.95363409, 0.5971223 , 0.96818182, 0.        , 0.        ],
#         [0.8358396 , 0.76978417, 0.96363636, 0.        , 0.        ],
#         [0.52130326, 0.48201439, 0.66818182, 0.        , 1.        ]]])

# %%
y_train
# Out:
# array([[0.4712215 , 0.62003052, 0.69810121, 0.6550818 , 0.61697889],
#        [0.62003052, 0.69810121, 0.6550818 , 0.61697889, 0.58807324],
#        [0.69810121, 0.6550818 , 0.61697889, 0.58807324, 0.6522421 ],
#        ...,
#        [0.85415784, 0.50461982, 0.51623294, 0.52767653, 0.91201153],
#        [0.50461982, 0.51623294, 0.52767653, 0.91201153, 0.55285242],
#        [0.51623294, 0.52767653, 0.91201153, 0.55285242, 0.77659574]])

# %%
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense

#np.random.seed(0)
model = Sequential()
model.add(SimpleRNN(100, input_shape=(5, 5)))
model.add(Dense(5, activation="linear"))
model.add(Dense(5, activation="relu"))
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

history = LossHistory() 
history.init()

hist = model.fit(X_train, y_train, epochs=90,batch_size=10, verbose=2,shuffle=False, callbacks=[history], validation_data=(X_test,y_test))
# print("Training Done! loss : %.4f  val_loss : %.4f"%(hist.history['loss'][-1],hist.history['val_loss'][-1]))
# Out:
# Train on 286 samples, validate on 67 samples
# Epoch 1/90
#  - 0s - loss: 0.1173 - acc: 0.1923 - val_loss: 0.0942 - val_acc: 0.1642
# Epoch 2/90
#  - 0s - loss: 0.0698 - acc: 0.2867 - val_loss: 0.0780 - val_acc: 0.2985
# Epoch 3/90
#  - 0s - loss: 0.0586 - acc: 0.4266 - val_loss: 0.0310 - val_acc: 0.4328
# Epoch 4/90
#  - 0s - loss: 0.0253 - acc: 0.5350 - val_loss: 0.0172 - val_acc: 0.4179
# Epoch 5/90
#  - 0s - loss: 0.0195 - acc: 0.5490 - val_loss: 0.0157 - val_acc: 0.3881
# Epoch 6/90
#  - 0s - loss: 0.0182 - acc: 0.5385 - val_loss: 0.0156 - val_acc: 0.4478
# Epoch 7/90
#  - 0s - loss: 0.0177 - acc: 0.5420 - val_loss: 0.0165 - val_acc: 0.4179
# Epoch 8/90
#  - 0s - loss: 0.0174 - acc: 0.5629 - val_loss: 0.0176 - val_acc: 0.4925
# Epoch 9/90
#  - 0s - loss: 0.0171 - acc: 0.5490 - val_loss: 0.0184 - val_acc: 0.4925
# Epoch 10/90
#  - 0s - loss: 0.0168 - acc: 0.5420 - val_loss: 0.0187 - val_acc: 0.4925
# Epoch 11/90
#  - 0s - loss: 0.0164 - acc: 0.5455 - val_loss: 0.0185 - val_acc: 0.4627
# Epoch 12/90
#  - 0s - loss: 0.0161 - acc: 0.5699 - val_loss: 0.0181 - val_acc: 0.4776
# Epoch 13/90
#  - 0s - loss: 0.0160 - acc: 0.5699 - val_loss: 0.0178 - val_acc: 0.4925
# Epoch 14/90
#  - 0s - loss: 0.0158 - acc: 0.5804 - val_loss: 0.0178 - val_acc: 0.4776
# Epoch 15/90
#  - 0s - loss: 0.0152 - acc: 0.5979 - val_loss: 0.0175 - val_acc: 0.5075
# Epoch 16/90
#  - 0s - loss: 0.0144 - acc: 0.6014 - val_loss: 0.0167 - val_acc: 0.4776
# Epoch 17/90
#  - 0s - loss: 0.0138 - acc: 0.5979 - val_loss: 0.0161 - val_acc: 0.5224
# Epoch 18/90
#  - 0s - loss: 0.0135 - acc: 0.5944 - val_loss: 0.0157 - val_acc: 0.5224
# Epoch 19/90
#  - 0s - loss: 0.0133 - acc: 0.5944 - val_loss: 0.0155 - val_acc: 0.5224
# Epoch 20/90
#  - 0s - loss: 0.0131 - acc: 0.5979 - val_loss: 0.0153 - val_acc: 0.5224
# Epoch 21/90
#  - 0s - loss: 0.0130 - acc: 0.5979 - val_loss: 0.0152 - val_acc: 0.5373
# Epoch 22/90
#  - 0s - loss: 0.0128 - acc: 0.5909 - val_loss: 0.0150 - val_acc: 0.5373
# Epoch 23/90
#  - 0s - loss: 0.0109 - acc: 0.6434 - val_loss: 0.0169 - val_acc: 0.5821
# Epoch 74/90
#  - 0s - loss: 0.0109 - acc: 0.6399 - val_loss: 0.0173 - val_acc: 0.5821
# Epoch 75/90
#  - 0s - loss: 0.0109 - acc: 0.6329 - val_loss: 0.0173 - val_acc: 0.5970
# Epoch 76/90
#  - 0s - loss: 0.0108 - acc: 0.6259 - val_loss: 0.0171 - val_acc: 0.6119
# Epoch 77/90
#  - 0s - loss: 0.0106 - acc: 0.6434 - val_loss: 0.0168 - val_acc: 0.6269
# Epoch 78/90
#  - 0s - loss: 0.0105 - acc: 0.6294 - val_loss: 0.0165 - val_acc: 0.6269
# Epoch 79/90
#  - 0s - loss: 0.0105 - acc: 0.6364 - val_loss: 0.0164 - val_acc: 0.6119
# Epoch 80/90
#  - 0s - loss: 0.0104 - acc: 0.6434 - val_loss: 0.0163 - val_acc: 0.5821
# Epoch 81/90
#  - 0s - loss: 0.0104 - acc: 0.6399 - val_loss: 0.0163 - val_acc: 0.5970
# Epoch 82/90
#  - 0s - loss: 0.0104 - acc: 0.6364 - val_loss: 0.0163 - val_acc: 0.6119
# Epoch 83/90
#  - 0s - loss: 0.0104 - acc: 0.6364 - val_loss: 0.0163 - val_acc: 0.5970
# Epoch 84/90
#  - 0s - loss: 0.0104 - acc: 0.6329 - val_loss: 0.0162 - val_acc: 0.6269
# Epoch 85/90
#  - 0s - loss: 0.0104 - acc: 0.6434 - val_loss: 0.0162 - val_acc: 0.6119
# Epoch 86/90
#  - 0s - loss: 0.0104 - acc: 0.6538 - val_loss: 0.0162 - val_acc: 0.5970
# Epoch 87/90
#  - 0s - loss: 0.0103 - acc: 0.6503 - val_loss: 0.0162 - val_acc: 0.5970
# Epoch 88/90
#  - 0s - loss: 0.0103 - acc: 0.6469 - val_loss: 0.0162 - val_acc: 0.5821
# Epoch 89/90
#  - 0s - loss: 0.0103 - acc: 0.6329 - val_loss: 0.0162 - val_acc: 0.5970
# Epoch 90/90
#  - 0s - loss: 0.0103 - acc: 0.6294 - val_loss: 0.0162 - val_acc: 0.6119

# %% [markdown]
# ## 6. 시각화 및 성능평가

# %%
plt.figure(figsize=(10,7))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.legend()
#plt.ylim(0.02,0.15)

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# 학습 시각화
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(history.losses)
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

model.evaluate(X_test, y_test)
yhat = model.predict(X_test)
rmse = sqrt(mean_squared_error(y_test, yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# 67/67 [==============================] - 0s 45us/step
# Test RMSE: 0.127

# %%
import matplotlib.pyplot as plt

fig, loss_ax = plt.subplots()


y_test_tuple = (y_test[0], y_test[1], y_test[2], y_test[3], 
                y_test[4], y_test[5], y_test[6])
y_hat_tuple = (yhat[0], yhat[1], yhat[2], 
               yhat[3], yhat[4], yhat[5], yhat[6])
acc_ax = loss_ax.twinx()
y_value = y['Consumo de cerveja (litros)'][-len(yhat):]
loss_ax.plot(np.concatenate(y_test_tuple), 'b', label='act')
# loss_ax.plot(hist.history['loss'], 'y', label='train loss')
loss_ax.plot(np.concatenate(y_hat_tuple), 'r', label='pred')

# acc_ax.legend(loc='lower left')
loss_ax.legend(loc='upper right')

plt.show()

# %% [markdown]
# # Beer Consumption 예측 using LSTM

# %%
# keras에서는 RNN계열의 모델을 트레이닝할 때 요구되는 데이터의 형식이 있다.
# 바로 3차원 데이터여야하며, 각각의 차원은(size, timestep, feature)
# timestep : 몇개의 특성으로 y 값을 맞출 거냐?

# %%
X_train.shape
# Out:
# (286, 5, 5)

# %%
y_train.shape
# Out:
# (286, 5)

# %%
from keras.layers import LSTM
from keras.models import Sequential
from keras.layers import Dense
import keras.backend as K
from keras.callbacks import EarlyStopping

# %%
K.clear_session()
model = Sequential()
model.add(LSTM(20, input_shape=(5,5))) # shape는 차원맞추는 것
model.add(Dense(5))  #Dense : output 개수 (이거 아닌듯!) -> layer의 갯수인듯 -> y값의 차원을 말하는거야.

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs = 100, batch_size=5, verbose=1)
# Out:
# Epoch 1/100
# 286/286 [==============================] - 1s 3ms/step - loss: 0.1151
# Epoch 2/100
# 286/286 [==============================] - 0s 530us/step - loss: 0.0268
# Epoch 3/100
# 286/286 [==============================] - 0s 513us/step - loss: 0.0252
# Epoch 4/100
# 286/286 [==============================] - 0s 520us/step - loss: 0.0237
# Epoch 5/100
# 286/286 [==============================] - 0s 520us/step - loss: 0.0226
# Epoch 6/100
# 286/286 [==============================] - 0s 537us/step - loss: 0.0216
# Epoch 7/100
# 286/286 [==============================] - 0s 537us/step - loss: 0.0208
# Epoch 8/100
# 286/286 [==============================] - 0s 506us/step - loss: 0.0202
# Epoch 9/100
# 286/286 [==============================] - 0s 520us/step - loss: 0.0194
# Epoch 10/100
# 286/286 [==============================] - 0s 520us/step - loss: 0.0189
# Epoch 11/100
# 286/286 [==============================] - 0s 568us/step - loss: 0.0184
# Epoch 12/100
# 286/286 [==============================] - 0s 572us/step - loss: 0.0181
# Epoch 13/100
# 286/286 [==============================] - 0s 516us/step - loss: 0.0177
# Epoch 14/100
# 286/286 [==============================] - 0s 534us/step - loss: 0.0172
# Epoch 15/100
# 286/286 [==============================] - 0s 586us/step - loss: 0.0169
# Epoch 16/100
# 286/286 [==============================] - 0s 530us/step - loss: 0.0166
# Epoch 17/100
# 286/286 [==============================] - 0s 603us/step - loss: 0.0163
# Epoch 18/100
# 286/286 [==============================] - 0s 565us/step - loss: 0.0160
# Epoch 19/100
# 286/286 [==============================] - 0s 541us/step - loss: 0.0157
# Epoch 20/100
# 286/286 [==============================] - 0s 607us/step - loss: 0.0153
# Epoch 21/100
# 286/286 [==============================] - 0s 534us/step - loss: 0.0154
# Epoch 22/100
# 286/286 [==============================] - 0s 554us/step - loss: 0.0150
# Epoch 23/100
# 286/286 [==============================] - 0s 582us/step - loss: 0.0148
# Epoch 24/100
# 286/286 [==============================] - 0s 534us/step - loss: 0.0146
# Epoch 25/100
# 286/286 [==============================] - 0s 596us/step - loss: 0.0145
# Epoch 26/100
# 286/286 [==============================] - 0s 558us/step - loss: 0.0143
# Epoch 27/100
# 286/286 [==============================] - 0s 520us/step - loss: 0.0142
# Epoch 65/100
# 286/286 [==============================] - 0s 694us/step - loss: 0.0111
# Epoch 66/100
# 286/286 [==============================] - 0s 670us/step - loss: 0.0112
# Epoch 67/100
# 286/286 [==============================] - 0s 715us/step - loss: 0.0111
# Epoch 68/100
# 286/286 [==============================] - 0s 670us/step - loss: 0.0110
# Epoch 69/100
# 286/286 [==============================] - 0s 704us/step - loss: 0.0111
# Epoch 70/100
# 286/286 [==============================] - 0s 687us/step - loss: 0.0109
# Epoch 71/100
# 286/286 [==============================] - 0s 690us/step - loss: 0.0108
# Epoch 72/100
# 286/286 [==============================] - 0s 722us/step - loss: 0.0111
# Epoch 73/100
# 286/286 [==============================] - 0s 683us/step - loss: 0.0111
# Epoch 74/100
# 286/286 [==============================] - 0s 809us/step - loss: 0.0111
# Epoch 75/100
# 286/286 [==============================] - 0s 799us/step - loss: 0.0111
# Epoch 76/100
# 286/286 [==============================] - 0s 837us/step - loss: 0.0109
# Epoch 77/100
# 286/286 [==============================] - 0s 757us/step - loss: 0.0109
# Epoch 78/100
# 286/286 [==============================] - 0s 729us/step - loss: 0.0109
# Epoch 79/100
# 286/286 [==============================] - 0s 732us/step - loss: 0.0110
# Epoch 80/100
# 286/286 [==============================] - 0s 781us/step - loss: 0.0109
# Epoch 81/100
# 286/286 [==============================] - 0s 809us/step - loss: 0.0111
# Epoch 82/100
# 286/286 [==============================] - 0s 802us/step - loss: 0.0108
# Epoch 83/100
# 286/286 [==============================] - 0s 750us/step - loss: 0.0109
# Epoch 84/100
# 286/286 [==============================] - 0s 670us/step - loss: 0.0109
# Epoch 85/100
# 286/286 [==============================] - 0s 711us/step - loss: 0.0107
# Epoch 86/100
# 286/286 [==============================] - 0s 771us/step - loss: 0.0108
# Epoch 87/100
# 286/286 [==============================] - 0s 711us/step - loss: 0.0107
# Epoch 88/100
# 286/286 [==============================] - 0s 861us/step - loss: 0.0109
# Epoch 89/100
# 286/286 [==============================] - 0s 882us/step - loss: 0.0108
# Epoch 90/100
# 286/286 [==============================] - 0s 861us/step - loss: 0.0109
# Epoch 91/100
# 286/286 [==============================] - 0s 771us/step - loss: 0.0105
# Epoch 92/100
# 286/286 [==============================] - 0s 778us/step - loss: 0.0105
# Epoch 93/100
# 286/286 [==============================] - 0s 718us/step - loss: 0.0105
# Epoch 94/100
# 286/286 [==============================] - 0s 774us/step - loss: 0.0106
# Epoch 95/100
# 286/286 [==============================] - 0s 722us/step - loss: 0.0106
# Epoch 96/100
# 286/286 [==============================] - 0s 767us/step - loss: 0.0108
# Epoch 97/100
# 286/286 [==============================] - 0s 722us/step - loss: 0.0104
# Epoch 98/100
# 286/286 [==============================] - 0s 656us/step - loss: 0.0105
# Epoch 99/100
# 286/286 [==============================] - 0s 631us/step - loss: 0.0107
# Epoch 100/100
# 286/286 [==============================] - 0s 645us/step - loss: 0.0104

# %%
from sklearn.metrics import mean_squared_error
import keras
from keras.layers import Dense, Dropout, LSTM
from math import sqrt

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([
#        [0.4315437 , 0.4746384 , 0.66023135, 0.6183191 , 0.29190785],
#        [0.49646896, 0.6868415 , 0.5279761 , 0.29795766, 0.40639925],
#        [0.7514636 , 0.5286325 , 0.28252375, 0.4081719 , 0.49867946],
#        [0.5851734 , 0.3220802 , 0.29753703, 0.47697267, 0.44371474],
#        [0.30865854, 0.34715766, 0.42524728, 0.43218672, 0.47685122],
#        [0.44038266, 0.4468243 , 0.38225418, 0.508419  , 0.786832  ],
#        [0.5055159 , 0.39996856, 0.43555772, 0.75941133, 0.7199268 ],
#        [0.39949876, 0.44720542, 0.7121363 , 0.70070094, 0.25795817],
#        [0.48469684, 0.74456704, 0.5616876 , 0.2794946 , 0.47303474],
#        [0.80726314, 0.5368069 , 0.309838  , 0.45559058, 0.49556482],
#        [0.6359485 , 0.32983148, 0.29455447, 0.4966823 , 0.47796088],
#        [0.27956825, 0.3428666 , 0.4342715 , 0.4424792 , 0.49314368],
#        [0.46495858, 0.48163128, 0.40217286, 0.51387894, 0.7742958 ],
#        [0.5069552 , 0.42713326, 0.44802007, 0.7563332 , 0.7535652 ],
#        [0.49390894, 0.47980303, 0.657858  , 0.7957865 , 0.59056413],
#        [0.5491385 , 0.7090832 , 0.68871945, 0.5913816 , 0.6274074 ],
#        [0.7806248 , 0.6847008 , 0.5924491 , 0.57070905, 0.46680528],
#        [0.79532826, 0.5964103 , 0.45572415, 0.47708166, 0.5235936 ],
#        [0.6455857 , 0.4636677 , 0.39403147, 0.514302  , 0.6097613 ],
#        [0.5570688 , 0.4669307 , 0.4146364 , 0.59387   , 0.79276764],
#        [0.440199  , 0.46177822, 0.53526545, 0.7524083 , 0.71698284],
#        [0.51479226, 0.54303217, 0.70207936, 0.7411644 , 0.4456169 ],
#        [0.5499067 , 0.71521753, 0.6267558 , 0.46227312, 0.5259037 ],
#        [0.76610863, 0.622689  , 0.4198298 , 0.48414084, 0.63498044],
#        [0.7147517 , 0.427184  , 0.41330776, 0.5798706 , 0.55991304],
#        [0.43047273, 0.42460042, 0.53583926, 0.4974007 , 0.43508828],
#        [0.46707624, 0.52056885, 0.50422734, 0.457619  , 0.5188865 ],
#        [0.63749856, 0.5468449 , 0.37875628, 0.49570715, 0.6708414 ],
#        [0.5999894 , 0.39880246, 0.4811454 , 0.6638741 , 0.42913282],
#        [0.4464084 , 0.5483391 , 0.55081415, 0.42309725, 0.357198  ]],
#       dtype=float32)

# %%
rmse = sqrt(mean_squared_error(y_test, y_pred))
print("RMSE:", rmse)
# Out:
# RMSE: 0.11938705743902063

# %% [markdown]
# output : 5개라서 이렇게 나오지~

# %%
fig, loss_ax = plt.subplots(figsize=(15,10))
acc_ax = loss_ax.twinx()

pred = y_pred

loss_ax.plot(pred, 'b', label='pred')

loss_ax.plot(y_test, 'r', label='act')

loss_ax.legend(loc='upper left')

plt.show()

# %% [markdown]
# ## 결론 : RNN < LSTM
#     RNN RMSE : 0.127
#
#     LSTM RMSE : 0.119
